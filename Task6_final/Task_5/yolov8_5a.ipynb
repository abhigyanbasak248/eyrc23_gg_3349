# %%
import cv2
import torch
import time
from ultralytics import YOLO
import json
model = YOLO('/home/shagnik/Downloads/best.pt')
cap = cv2.VideoCapture(2)

x = 0
start = time.time()

labels=["blank","combat","destroyed_buildings","fire","human_aid_rehabiliation","military_vehicles"]
mid_y=[]
ca=[]
i=1
while True:
    ret, frame = cap.read()
    if not ret:
        continue

    results = model(frame)
    for r in results:
        for ra in r.boxes.data:
            # Extracting bounding box coordinates
            x_min, y_min, x_max, y_max = map(int, ra[:4])
            c=int(ra[5])
            # Setting the color (BGR format, e.g., (0, 255, 0) for green)
            color = (0, 255, 0)  # You can change this color as per your preference
            cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), color, 2)
            cv2.putText(frame,labels[c],(x_min,y_min-10),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,255,0),2,3)
            mid_y.append((y_min+y_max)/2)
            ca.append(c)
        if True:
            break
    if len(mid_y)>0 and i>0:
        g=list(zip(mid_y,ca))
        g=sorted(g,key=lambda x:x[0])
        s_y,s_c=zip(*g)
        print(s_c)
        s_c=list(s_c)
        n=[]
        for j in range(0,5):
            n.append(labels[s_c[j]])
        print(n)
        ele_dict=dict(zip(['E','D','C','B','A'],n))
        if(len(s_y))==5:
            print(ele_dict)
            file_path="file.txt"
            with open(file_path,"w") as file:
                json.dump(ele_dict,file)
        i=-1
    frame= cv2.resize(frame, (960, 985))
    cv2.imshow('frames', frame)

    x += 1

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

end = time.time()

print(x / (end - start), "fps")
# Out:
# 0: 480x640 (no detections), 471.8ms
# Speed: 5.0ms preprocess, 471.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 307.2ms
# Speed: 1.8ms preprocess, 307.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# (0, 5, 0, 0, 3)
# ['blank', 'military_vehicles', 'blank', 'blank', 'fire']
# {'E': 'blank', 'D': 'military_vehicles', 'C': 'blank', 'B': 'blank', 'A': 'fire'}
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 375.9ms
# Speed: 1.9ms preprocess, 375.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 331.8ms
# Speed: 1.8ms preprocess, 331.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 333.3ms
# Speed: 1.4ms preprocess, 333.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 322.1ms
# Speed: 1.3ms preprocess, 322.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 318.2ms
# Speed: 1.5ms preprocess, 318.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 332.5ms
# Speed: 1.5ms preprocess, 332.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 477.7ms
# Speed: 1.8ms preprocess, 477.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 489.2ms
# Speed: 1.9ms preprocess, 489.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 338.3ms
# Speed: 2.0ms preprocess, 338.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 332.9ms
# Speed: 1.6ms preprocess, 332.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 497.9ms
# Speed: 1.7ms preprocess, 497.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 344.0ms
# Speed: 1.7ms preprocess, 344.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 351.8ms
# Speed: 1.9ms preprocess, 351.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 490.0ms
# Speed: 2.0ms preprocess, 490.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 331.5ms
# Speed: 2.8ms preprocess, 331.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 348.2ms
# Speed: 1.9ms preprocess, 348.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 313.1ms
# Speed: 1.6ms preprocess, 313.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 355.5ms
# Speed: 1.7ms preprocess, 355.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 350.4ms
# Speed: 2.4ms preprocess, 350.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 317.7ms
# Speed: 2.5ms preprocess, 317.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 313.0ms
# Speed: 2.5ms preprocess, 313.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 381.6ms
# Speed: 1.7ms preprocess, 381.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 340.0ms
# Speed: 1.6ms preprocess, 340.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 483.1ms
# Speed: 1.7ms preprocess, 483.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 505.7ms
# Speed: 1.8ms preprocess, 505.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 346.1ms
# Speed: 1.5ms preprocess, 346.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 349.4ms
# Speed: 1.6ms preprocess, 349.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 335.7ms
# Speed: 1.7ms preprocess, 335.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 494.4ms
# Speed: 1.8ms preprocess, 494.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 484.2ms
# Speed: 2.8ms preprocess, 484.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 470.6ms
# Speed: 2.9ms preprocess, 470.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 419.4ms
# Speed: 2.1ms preprocess, 419.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 345.9ms
# Speed: 2.2ms preprocess, 345.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 468.9ms
# Speed: 2.0ms preprocess, 468.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 480.7ms
# Speed: 1.8ms preprocess, 480.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 485.6ms
# Speed: 1.8ms preprocess, 485.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 493.5ms
# Speed: 1.9ms preprocess, 493.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 373.7ms
# Speed: 3.4ms preprocess, 373.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 333.1ms
# Speed: 1.5ms preprocess, 333.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 470.2ms
# Speed: 1.8ms preprocess, 470.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 468.2ms
# Speed: 2.3ms preprocess, 468.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 449.6ms
# Speed: 2.2ms preprocess, 449.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 357.6ms
# Speed: 1.7ms preprocess, 357.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 378.2ms
# Speed: 1.7ms preprocess, 378.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 487.4ms
# Speed: 3.0ms preprocess, 487.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 338.9ms
# Speed: 2.3ms preprocess, 338.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 471.1ms
# Speed: 1.6ms preprocess, 471.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 451.7ms
# Speed: 2.7ms preprocess, 451.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 472.1ms
# Speed: 2.3ms preprocess, 472.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 344.3ms
# Speed: 1.4ms preprocess, 344.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 337.3ms
# Speed: 1.5ms preprocess, 337.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 335.4ms
# Speed: 1.4ms preprocess, 335.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 468.6ms
# Speed: 1.5ms preprocess, 468.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 315.7ms
# Speed: 1.5ms preprocess, 315.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 483.9ms
# Speed: 1.9ms preprocess, 483.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 349.9ms
# Speed: 2.0ms preprocess, 349.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 453.3ms
# Speed: 2.6ms preprocess, 453.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 347.1ms
# Speed: 1.8ms preprocess, 347.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 384.5ms
# Speed: 2.6ms preprocess, 384.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 496.9ms
# Speed: 5.1ms preprocess, 496.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 372.2ms
# Speed: 2.4ms preprocess, 372.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 blanks, 1 fire, 1 military_vehicles, 326.5ms
# Speed: 1.7ms preprocess, 326.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# 2.238972749520509 fps
